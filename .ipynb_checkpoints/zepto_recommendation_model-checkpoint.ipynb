# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('session_data.csv')

# %%
data
# Out:
#                               session_id          product_name
# 0       000ed966131fcb96e0efc4ff2b716a3e              beetroot
# 1       000ed966131fcb96e0efc4ff2b716a3e              cucumber
# 2       0013eab657eaf2d82d7f1e13023d95c2                 onion
# 3       0013eab657eaf2d82d7f1e13023d95c2  long shelf life milk
# 4       0013fabde1e543dd541be925266aadbc                 dates
# ...                                  ...                   ...
# 345147  ffb73de5b022d80d23ec72a7ce8226fe  long shelf life milk
# 345148  ffb73de5b022d80d23ec72a7ce8226fe         nectar juices
# 345149  ffb73de5b022d80d23ec72a7ce8226fe                 onion
# 345150  ffcb72279f578ca4cb32c089d8fe8aa4                  rice
# 345151  ffcb72279f578ca4cb32c089d8fe8aa4                 onion
#
# [345152 rows x 2 columns]

# %%
data.describe()
# Out:
#                               session_id product_name
# count                             345152       345152
# unique                            165335          396
# top     27d86d946e6ea6d022f12211d61f8ac7        onion
# freq                                   9        31196

# %%
product_name_distribution = data['product_name'].value_counts()
top_10_products = product_name_distribution.head(10)
colors = sns.color_palette("viridis", len(top_10_products))
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_products.values, y=top_10_products.index, palette=colors)
plt.xlabel('Count')
plt.ylabel('Product Name')
plt.title('Top 10 Most Common Products')
plt.show()

# %%
products_per_session = data.groupby('session_id')['product_name'].count()
plt.figure(figsize=(10, 6))
sns.histplot(products_per_session, bins=20, kde=True, color='skyblue')
plt.xlabel('Number of Products per Session')
plt.ylabel('Frequency')
plt.title('Distribution of Products per Session')
plt.show()
# Out:
# C:\Users\VICTUS\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
unique_products_per_session = data.groupby('session_id')['product_name'].nunique()
top_sessions = unique_products_per_session.nlargest(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=top_sessions.values, y=top_sessions.index, palette="viridis")
plt.xlabel('Number of Unique Products')
plt.ylabel('Session ID')
plt.title('Top 10 Sessions with Most Unique Products')
plt.show()

# %%
from itertools import combinations
from collections import Counter
sessions = data.groupby('session_id')['product_name'].apply(list).tolist()
comb_counts = Counter()
for session in sessions:
    comb_counts.update(combinations(session, 2))
most_common_combinations = comb_counts.most_common(10)
most_common_combinations_df = pd.DataFrame(most_common_combinations, columns=['Combination', 'Count'])
most_common_combinations_df['Combination'] = most_common_combinations_df['Combination'].apply(lambda x: ' & '.join(x))
plt.figure(figsize=(12, 6))
sns.barplot(x='Count', y='Combination', data=most_common_combinations_df, palette="viridis")
plt.xlabel('Count')
plt.ylabel('Product Combination')
plt.title('Top 10 Most Common Product Combinations')
plt.show()

# %%
data_rec = data.pivot_table(index='product_name',columns='session_id',aggfunc=lambda x: 1, fill_value=0)

# %%
data_rec
# Out:
# session_id                  0000bc46bf70d6ebb01c8b58f5e619ab  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  000163cb20c349ae5d6b9cd3343a221a  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  0001978dc214c82cb21a5a3d450ba431  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  0001c0bc9fcff00481a997d89de3d2e0  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 1
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  0002276867f6d276dc39a3261e30b2ca  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     1
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  0002a1009370d0d675e449a32f94f711  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  0002e76e639563ab3a7c7cfca6033c07  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  0004023b626e58a7e4cea8d90f4ed63e  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  00045195505b4724ee770cd23074458d  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  00047a22fc404e52e15cbcf3879567ff  ...  \
# product_name                                                  ...
# a2 ghee                                                    0  ...
# adult diapers                                              0  ...
# adult nutrition                                            0  ...
# agarbatti & incense sticks                                 0  ...
# almond                                                     0  ...
# ...                                                      ...  ...
# white eggs                                                 0  ...
# whole wheat breads                                         0  ...
# woks                                                       0  ...
# yoghurt                                                    0  ...
# zucchini                                                   0  ...
#
# session_id                  fffde145d14d31cb7210ba3bf856fc8d  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  fffdffe99c2975e6f261fc590e033072  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  fffe547fe948f699a37a639553ac48d9  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  fffe624d79b71263fec13d4ddd1e5692  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  fffed0f986ae3933f0830538adc37864  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  fffed3a44b22a0ad079f5ecf75c38e75  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  ffff24612f86e176e835ca50a98182e1  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  ffffdfdb1e329a1ffde4f7eef3ff01d8  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  ffffeeaa83df2ff6c902dadae7e6ed75  \
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# session_id                  fffffcd6989cd65bc9dd67e13d6dadff
# product_name
# a2 ghee                                                    0
# adult diapers                                              0
# adult nutrition                                            0
# agarbatti & incense sticks                                 0
# almond                                                     0
# ...                                                      ...
# white eggs                                                 0
# whole wheat breads                                         0
# woks                                                       0
# yoghurt                                                    0
# zucchini                                                   0
#
# [396 rows x 165335 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity_score = cosine_similarity(data_rec)
similarity_score.shape
# Out:
# (396, 396)

# %%
def recommend(item_name,similarity_score):
    items = []
    similarity_score = np.array(similarity_score)
    if item_name not in data_rec.index:
        print('Book not found in the dataset.')
        return
    
    index = np.where(data_rec.index == item_name)[0]
    if len(index) == 0:
        print('No similar books found')
    else:
        index = index[0]
        similar_item = sorted(list(enumerate(similarity_score[index])), key=lambda x: x[1], reverse=True)[1:6]
        for i in similar_item:
            items.append(data_rec.index[i[0]])
            print(data_rec.index[i[0]])
    return items

# %%
recommend('yoghurt',similarity_score)
# Out:
# curd
# chocolates
# protein bar
# cakes
# blueberry
# ['curd', 'chocolates', 'protein bar', 'cakes', 'blueberry']
